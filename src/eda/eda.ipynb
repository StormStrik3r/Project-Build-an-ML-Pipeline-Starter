# %%
# !pip install wandb==0.16.0
# !pip install ydata-profiling==4.12.1
# !pip install pandas==2.1.3
# Out:
# Requirement already satisfied: wandb==0.16.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (8.1.8)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (3.1.44)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (2.32.3)
# Requirement already satisfied: psutil>=5.0.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (7.0.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (2.25.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (0.4.0)
# Requirement already satisfied: PyYAML in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (6.0.2)
# Requirement already satisfied: setproctitle in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (1.3.5)
# Requirement already satisfied: setuptools in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (78.1.0)
# Requirement already satisfied: appdirs>=1.4.3 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (4.25.6)
# Requirement already satisfied: six>=1.4.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb==0.16.0) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.0) (4.0.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.0) (5.0.2)
# Collecting ydata-profiling==4.12.1
#   Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl.metadata (20 kB)
# Collecting scipy<1.14,>=1.4.1 (from ydata-profiling==4.12.1)
#   Downloading scipy-1.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (2.1.3)
# Requirement already satisfied: matplotlib<3.10,>=3.5 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (3.8.2)
# Collecting pydantic>=2 (from ydata-profiling==4.12.1)
#   Downloading pydantic-2.11.2-py3-none-any.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (3.1.6)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1)
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (1.26.4)
# Collecting htmlmin==0.1.12 (from ydata-profiling==4.12.1)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling==4.12.1)
#   Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (2.32.3)
# Collecting tqdm<5,>=4.48.2 (from ydata-profiling==4.12.1)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting seaborn<0.14,>=0.10.1 (from ydata-profiling==4.12.1)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting multimethod<2,>=1.4 (from ydata-profiling==4.12.1)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling==4.12.1)
#   Downloading statsmodels-0.14.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling==4.12.1)
#   Downloading typeguard-4.4.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling==4.12.1)
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling==4.12.1)
#   Downloading wordcloud-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling==4.12.1)
#   Using cached dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<1,>=0.56.0 (from ydata-profiling==4.12.1)
#   Downloading numba-0.61.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling==4.12.1)
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling==4.12.1) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==4.12.1) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (2.9.0.post0)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba<1,>=0.56.0->ydata-profiling==4.12.1)
#   Downloading llvmlite-0.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->ydata-profiling==4.12.1) (1.4.2)
# Collecting annotated-types>=0.6.0 (from pydantic>=2->ydata-profiling==4.12.1)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.1 (from pydantic>=2->ydata-profiling==4.12.1)
#   Downloading pydantic_core-2.33.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pydantic>=2->ydata-profiling==4.12.1) (4.13.1)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2->ydata-profiling==4.12.1)
#   Using cached typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2025.1.31)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling==4.12.1)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1) (25.3.0)
# Collecting networkx>=2.4 (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# WARNING: visions 0.7.6 does not provide the extra 'type-image-path'
# Requirement already satisfied: six>=1.5 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.17.0)
# Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 11.5 MB/s eta 0:00:00
# Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Using cached dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.61.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 51.4 MB/s eta 0:00:00m eta 0:00:010:01
# Downloading phik-0.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (686 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 33.9 MB/s eta 0:00:00
# Downloading pydantic-2.11.2-py3-none-any.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.3/443.3 kB 28.4 MB/s eta 0:00:00
# Downloading pydantic_core-2.33.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 47.8 MB/s eta 0:00:000m eta 0:00:01
# Downloading scipy-1.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 41.1 MB/s eta 0:00:000m eta 0:00:010:00:01
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading statsmodels-0.14.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 72.0 MB/s eta 0:00:000m eta 0:00:0136m0:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typeguard-4.4.2-py3-none-any.whl (35 kB)
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 8.3 MB/s eta 0:00:00
# Downloading wordcloud-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.1/511.1 kB 35.2 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading llvmlite-0.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 35.5 MB/s eta 0:00:000m eta 0:00:010:00:01
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 44.6 MB/s eta 0:00:000m eta 0:00:01
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Using cached typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 60.5 MB/s eta 0:00:000m eta 0:00:010:00:01
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27160 sha256=aae9727f0391b36197daef9a8c535e9a843d0cc232bf430aa265f813e7a2be2b
#   Stored in directory: /home/corbin/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# Installing collected packages: htmlmin, typing-inspection, typeguard, tqdm, scipy, PyWavelets, pydantic-core, patsy, networkx, multimethod, llvmlite, dacite, annotated-types, pydantic, numba, imagehash, wordcloud, visions, statsmodels, seaborn, phik, ydata-profiling
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
# Successfully installed PyWavelets-1.8.0 annotated-types-0.7.0 dacite-1.9.2 htmlmin-0.1.12 imagehash-4.3.1 llvmlite-0.44.0 multimethod-1.12 networkx-3.4.2 numba-0.61.0 patsy-1.0.1 phik-0.12.4 pydantic-2.11.2 pydantic-core-2.33.1 scipy-1.13.1 seaborn-0.13.2 statsmodels-0.14.4 tqdm-4.67.1 typeguard-4.4.2 typing-inspection-0.4.0 visions-0.7.6 wordcloud-1.9.4 ydata-profiling-4.12.1
# Requirement already satisfied: pandas==2.1.3 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas==2.1.3) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas==2.1.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas==2.1.3) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas==2.1.3) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/corbin/.conda/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.1.3) (1.17.0)

# %% [markdown]
# 1. Fetch the artifact we just created (sample.csv) from W&B and read it with pandas:

# %%
import wandb
import pandas as pd
# Note that we use save_code=True in the call to wandb.init so the notebook is uploaded and versioned by W&B
run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# wandb: Currently logged in as: stormstrik3r (stormstrik3r-western-governors-university). Use `wandb login --relogin` to force relogin
# wandb version 0.19.9 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/home/corbin/Project-Build-an-ML-Pipeline-Starter/src/eda/wandb/run-20250407_200048-f1hr014e</code>
# Syncing run <strong><a href='https://wandb.ai/stormstrik3r-western-governors-university/nyc_airbnb/runs/f1hr014e' target="_blank">lively-cosmos-2</a></strong> to <a href='https://wandb.ai/stormstrik3r-western-governors-university/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/stormstrik3r-western-governors-university/nyc_airbnb' target="_blank">https://wandb.ai/stormstrik3r-western-governors-university/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/stormstrik3r-western-governors-university/nyc_airbnb/runs/f1hr014e' target="_blank">https://wandb.ai/stormstrik3r-western-governors-university/nyc_airbnb/runs/f1hr014e</a>

# %% [markdown]
# 2. Explore the data in df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20000 non-null  int64
#  1   name                            19993 non-null  object
#  2   host_id                         20000 non-null  int64
#  3   host_name                       19992 non-null  object
#  4   neighbourhood_group             20000 non-null  object
#  5   neighbourhood                   20000 non-null  object
#  6   latitude                        20000 non-null  float64
#  7   longitude                       20000 non-null  float64
#  8   room_type                       20000 non-null  object
#  9   price                           20000 non-null  int64
#  10  minimum_nights                  20000 non-null  int64
#  11  number_of_reviews               20000 non-null  int64
#  12  last_review                     15877 non-null  object
#  13  reviews_per_month               15877 non-null  float64
#  14  calculated_host_listings_count  20000 non-null  int64
#  15  availability_365                20000 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.000000e+04  2.000000e+04  20000.000000  20000.000000  20000.000000
# mean   1.892380e+07  6.746034e+07     40.728455    -73.952125    153.269050
# std    1.101223e+07  7.857936e+07      0.054755      0.046559    243.325609
# min    2.539000e+03  2.571000e+03     40.508730    -74.239140      0.000000
# 25%    9.393540e+06  7.853718e+06     40.689420    -73.983030     69.000000
# 50%    1.952117e+07  3.111431e+07     40.722730    -73.955640    105.000000
# 75%    2.912936e+07  1.068426e+08     40.762990    -73.936380    175.000000
# max    3.648561e+07  2.742733e+08     40.913060    -73.717950  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20000.000000       20000.000000       15877.000000
# mean         6.992100          23.274100           1.377446
# std         21.645449          44.927793           1.683006
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          2.000000           5.000000           0.720000
# 75%          5.000000          23.000000           2.010000
# max       1250.000000         607.000000          27.950000
#
#        calculated_host_listings_count  availability_365
# count                    20000.000000      20000.000000
# mean                         6.955450        112.901200
# std                         32.433831        131.762226
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         44.000000
# 75%                          2.000000        229.000000
# max                        327.000000        365.000000

# %%
df.head(20)
# Out:
#           id                                               name    host_id  \
# 0    9138664                Private Lg Room 15 min to Manhattan   47594947
# 1   31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2    8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3   34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4   23203149   Big beautiful bedroom in huge Bushwick apartment     143460
# 5    4402805         LRG 2br BKLYN APT CLOSE TO TRAINS AND PARK   22807362
# 6   30070126  ✩Prime Renovated 1/1 Apartment in Upper East S...    4968673
# 7   34231172      Fully renovated brick house floor in Brooklyn   59642348
# 8    5856760         Renovated 1BR in exciting, convenient area   29408349
# 9    7929441                 Beautiful Loft w/ Waterfront View!    1453898
# 10  35468220            Forest Hills Charming 1 bdrm apartment!    7599704
# 11  18340498    Private bedroom and bathroom near Prospect Park   33723491
# 12     34760    Sunny Room in Old Historical Brooklyn Townhouse     149929
# 13  15982208          Huge Yellow Room- AC, 20 Min to Manhattan  103841276
# 14  14994076   Dominiques NYC 4Bedrm crashpad**Stay here**metro     310670
# 15   7126110                         Sunny East Village Bedroom   37325763
# 16  35005489                      Exquisite Park Slope Paradise  229604812
# 17  22702906      Cozy Brownstone Brooklyn Studio Near Subway!!    6291509
# 18  25015496   5min from JFK airport, Train, Casino,  Racetrack  189108951
# 19   7074488                Bilevel Penthouse: Park, City Views      43772
#
#              host_name neighbourhood_group              neighbourhood  \
# 0                 Iris              Queens                  Sunnyside
# 1               Johlex           Manhattan             Hell's Kitchen
# 2                 John           Manhattan               West Village
# 3                Regan              Queens                    Astoria
# 4                Megan            Brooklyn                   Bushwick
# 5                Jenny            Brooklyn  Prospect-Lefferts Gardens
# 6                 Sean           Manhattan            Upper East Side
# 7                Kevin            Brooklyn                Sunset Park
# 8                 Chad           Manhattan                  Chinatown
# 9              Anthony            Brooklyn               Williamsburg
# 10               Sasha              Queens               Forest Hills
# 11            Suzzanne            Brooklyn                   Flatbush
# 12                Obed            Brooklyn                Fort Greene
# 13  Cristina And Sasha            Brooklyn                   Bushwick
# 14                 Vie               Bronx                Eastchester
# 15                Noah           Manhattan               East Village
# 16                Jake            Brooklyn            Windsor Terrace
# 17              Daniel            Brooklyn                Boerum Hill
# 18               Doris              Queens           South Ozone Park
# 19               David            Brooklyn                 Greenpoint
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 0   40.74271  -73.92493     Private room     74               2
# 1   40.76682  -73.98878  Entire home/apt    170               3
# 2   40.73631  -74.00611  Entire home/apt    245               3
# 3   40.76424  -73.92351  Entire home/apt    125               3
# 4   40.69839  -73.92044     Private room     65               2
# 5   40.66025  -73.96270  Entire home/apt    120               3
# 6   40.76831  -73.95929  Entire home/apt    200               5
# 7   40.64550  -74.01262  Entire home/apt     95               1
# 8   40.71490  -73.99976  Entire home/apt    179               5
# 9   40.71268  -73.96676     Private room    105               2
# 10  40.72085  -73.84088  Entire home/apt     75               1
# 11  40.65274  -73.95848     Private room     39               2
# 12  40.69101  -73.97312     Private room     44               8
# 13  40.69891  -73.93072     Private room     45               1
# 14  40.88207  -73.83538  Entire home/apt    299               2
# 15  40.72393  -73.98271     Private room    100               1
# 16  40.65863  -73.98495  Entire home/apt    300               3
# 17  40.68760  -73.98472  Entire home/apt    160               4
# 18  40.66954  -73.80601  Entire home/apt     93               2
# 19  40.72074  -73.94741  Entire home/apt    272               3
#
#     number_of_reviews last_review  reviews_per_month  \
# 0                   6  2019-05-26               0.13
# 1                   0         NaN                NaN
# 2                  51  2018-09-19               1.12
# 3                   1  2019-05-24               0.65
# 4                   8  2019-06-23               0.52
# 5                   3  2018-08-28               0.05
# 6                   2  2019-05-26               0.68
# 7                   9  2019-07-08               9.00
# 8                   7  2017-04-18               0.14
# 9                 232  2019-06-19               5.00
# 10                  0         NaN                NaN
# 11                  7  2017-09-29               0.27
# 12                 27  2019-06-29               1.05
# 13                158  2019-06-25               4.93
# 14                  2  2019-05-21               0.18
# 15                  0         NaN                NaN
# 16                  0         NaN                NaN
# 17                  4  2018-09-26               0.30
# 18                 48  2019-06-22               3.47
# 19                  3  2015-08-31               0.06
#
#     calculated_host_listings_count  availability_365
# 0                                1                 5
# 1                                1               188
# 2                                1                 0
# 3                                1                13
# 4                                2                 8
# 5                                1                16
# 6                                1                71
# 7                                1               106
# 8                                1                 0
# 9                                3                64
# 10                               1                 7
# 11                               1                 0
# 12                               5               280
# 13                               2               201
# 14                              13               358
# 15                               1                 0
# 16                               1               335
# 17                               1                14
# 18                               1               316
# 19                               1                 0

# %% [markdown]
# 3. What do you notice in the data? Look around and see what you can find.
#
# > For example, there are missing values in a few columns and the column `last_review` is a date but it is in string format. Look also at the `price` column, and note the outliers. There are some zeros and some very high prices. After talking to your stakeholders, you decide to consider from a minimum of `$10` to a maximum of `$350` per night.

# %% [markdown]
# 4. Fix some of the little problems we have found in the data with the following code:

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %% [markdown]
# Note how we did not impute missing values. We will do that in the inference pipeline, so we will be able to handle missing values also in production.

# %% [markdown]
# 5. Check with df.info() that all obvious problems have been solved

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %% [markdown]
# 6. Terminate the run by running `run.finish()`

# %%
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">lively-cosmos-2</strong> at: <a href='https://wandb.ai/stormstrik3r-western-governors-university/nyc_airbnb/runs/f1hr014e' target="_blank">https://wandb.ai/stormstrik3r-western-governors-university/nyc_airbnb/runs/f1hr014e</a><br/> View job at <a href='https://wandb.ai/stormstrik3r-western-governors-university/nyc_airbnb/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjYwNzE5NDYwNg==/version_details/v0' target="_blank">https://wandb.ai/stormstrik3r-western-governors-university/nyc_airbnb/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjYwNzE5NDYwNg==/version_details/v0</a><br/>Synced 7 W&B file(s), 0 media file(s), 3 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20250407_200048-f1hr014e/logs</code>

# %% [markdown]
# 7. Save the notebook.
